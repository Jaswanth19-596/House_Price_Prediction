# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('house_price_regression_dataset.csv')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981      0.60
# 1            4272             3              3        2016      4.75
# 2            3592             1              2        2016      3.63
# 3             966             1              2        1977      2.73
# 4            4926             2              1        1993      4.70
#
#    Garage_Size  Neighborhood_Quality  House_Price
# 0            0                     5   262,382.85
# 1            1                     6   985,260.85
# 2            0                     9   777,977.39
# 3            1                     8   229,698.92
# 4            0                     8 1,041,740.86

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### 1. Square_Footage

# %%
df['Square_Footage'].describe()
# Out:
# count   1,000.00
# mean    2,815.42
# std     1,255.51
# min       503.00
# 25%     1,749.50
# 50%     2,862.50
# 75%     3,849.50
# max     4,999.00
# Name: Square_Footage, dtype: float64

# %%
sns.kdeplot(df['Square_Footage'])
# Out:
# <Axes: xlabel='Square_Footage', ylabel='Density'>

# %%
df['Square_Footage'].kurtosis()
# Out:
# np.float64(-1.1280610906307573)

# %%
sns.boxplot(df['Square_Footage'])
# Out:
# <Axes: ylabel='Square_Footage'>

# %% [markdown]
# ##### Observations
#   - The data doesn't have any outliers, missing values.
#   - Very well distributed.

# %% [markdown]
# ### 2. Num_Bedrooms

# %%
df['Num_Bedrooms'].value_counts()
# Out:
# Num_Bedrooms
# 2    215
# 5    205
# 1    201
# 4    197
# 3    182
# Name: count, dtype: int64

# %%
sns.barplot(df['Num_Bedrooms'].value_counts())
# Out:
# <Axes: xlabel='Num_Bedrooms', ylabel='count'>

# %% [markdown]
# ##### Observations
#   - The distribution is perfect.
#   - There are no missing values.

# %% [markdown]
# ### 3. Num_Bathrooms

# %%
df['Num_Bathrooms'].value_counts()
# Out:
# Num_Bathrooms
# 1    350
# 2    327
# 3    323
# Name: count, dtype: int64

# %%
sns.barplot(df['Num_Bathrooms'].value_counts())
# Out:
# <Axes: xlabel='Num_Bathrooms', ylabel='count'>

# %% [markdown]
# ##### Observations
#
#   - The Distribution is good.
#   - No Missing values.

# %% [markdown]
# ### 4. Year_Built

# %%
sns.barplot(df['Year_Built'].value_counts())
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### Observations
#   - The data is evenly distributed across all the years.
#   - There are some years where the houses built are less in between but the next year they are being complemented.

# %% [markdown]
# ### 5.Lot_Size

# %%
sns.histplot(df['Lot_Size'], bins = 10)
# Out:
# <Axes: xlabel='Lot_Size', ylabel='Count'>

# %%
sns.boxplot(df['Lot_Size'])
# Out:
# <Axes: ylabel='Lot_Size'>

# %% [markdown]
# ##### Observations
# - The distribution is good.
# - No outliers and missing values.

# %% [markdown]
# ### 6. Garage_Size

# %%
sns.barplot(df['Garage_Size'].value_counts())
# Out:
# <Axes: xlabel='Garage_Size', ylabel='count'>

# %% [markdown]
# ### 7. Neighborhood_Quality

# %%
sns.barplot(df['Neighborhood_Quality'].value_counts())
# Out:
# <Axes: xlabel='Neighborhood_Quality', ylabel='count'>

# %% [markdown]
# ### 10. House_Price

# %%
sns.histplot(df['House_Price'], bins = 10)
# Out:
# <Axes: xlabel='House_Price', ylabel='Count'>

# %%
sns.kdeplot(df['House_Price'])
# Out:
# <Axes: xlabel='House_Price', ylabel='Density'>

# %%
sns.boxplot(df['House_Price'])
# Out:
# <Axes: ylabel='House_Price'>
